# %% [markdown]
# Requirement: Start looking at the compensation data set and start to figure out how to put the two data sources together.
# Source: Compensation data, WRDS data.
# And I chose to use jupyter notebook.

# %% [markdown]
# ## 1. Preparation
# Preparation work includes installing modules and importing libraries (i.e., numpy, pandas, datetime, wrds) that I tended to use during coding.

# %% [markdown]
# ### 1.1 Install 'wrds' module

# %%
pip install wrds
# Out:
# Requirement already satisfied: wrds in /Users/minqi/opt/anaconda3/lib/python3.8/site-packages (3.0.10)
# Requirement already satisfied: sqlalchemy in /Users/minqi/opt/anaconda3/lib/python3.8/site-packages (from wrds) (1.4.7)
# Requirement already satisfied: mock in /Users/minqi/opt/anaconda3/lib/python3.8/site-packages (from wrds) (4.0.3)
# Requirement already satisfied: numpy in /Users/minqi/opt/anaconda3/lib/python3.8/site-packages (from wrds) (1.20.1)
# Requirement already satisfied: psycopg2-binary in /Users/minqi/opt/anaconda3/lib/python3.8/site-packages (from wrds) (2.9.1)
# Requirement already satisfied: pandas in /Users/minqi/opt/anaconda3/lib/python3.8/site-packages (from wrds) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/minqi/opt/anaconda3/lib/python3.8/site-packages (from pandas->wrds) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/minqi/opt/anaconda3/lib/python3.8/site-packages (from pandas->wrds) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/minqi/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->wrds) (1.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/minqi/opt/anaconda3/lib/python3.8/site-packages (from sqlalchemy->wrds) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 1.2 Import libraries

# %%
import numpy as np
import pandas as pd
import datetime as dt
import wrds

# %% [markdown]
# ### 1.3 Look at basic information about 'wrds'

# %%
help(wrds)
# Out:
# Help on package wrds:
#
# NAME
#     wrds
#
# DESCRIPTION
#     WRDS Python Data Access Library
#     ==============================
#
#     WRDS-Py is a library for extracting data from WRDS data sources and getting it into Pandas.
#
#         >>> import wrds
#         >>> db = wrds.Connection()
#         >>> db.list_libraries()
#         ['aha', 'aha_sample', 'ahasamp', 'audit', 'audit_audit_comp', ...]
#         >>> db.list_tables(library='crsp')
#         ['acti', 'asia', 'asib', 'asic', 'asio', 'asix', 'bmdebt', 'bmheader', ...]
#         >>> data = db.raw_sql('SELECT * FROM crsp.stocknames', index_col='permno')
#         >>> data.head()
#                  permco      namedt   nameenddt     cusip    ncusip ticker      permno
#         10000.0  7952.0  1986-01-07  1987-06-11  68391610  68391610  OMFGA
#         10001.0  7953.0  1986-01-09  1993-11-21  36720410  39040610   GFGC
#         10001.0  7953.0  1993-11-22  2008-02-04  36720410  29274A10   EWST
#         10001.0  7953.0  2008-02-05  2009-08-03  36720410  29274A20   EWST
#         10001.0  7953.0  2009-08-04  2009-12-17  36720410  29269V10   EGAS
#         ...
#
# PACKAGE CONTENTS
#     sql
#     test
#
# DATA
#     __copyright__ = '2017-2021 Wharton Research Data Services'
#     __title__ = 'wrds-py'
#
# VERSION
#     3.0.10
#
# AUTHOR
#     Wharton Research Data Services
#
# FILE
#     /Users/minqi/opt/anaconda3/lib/python3.8/site-packages/wrds/__init__.py

# %% [markdown]
# ### 1.4 Get connected with wrds using my wrds account

# %%
conn=wrds.Connection()
# Out:
# Enter your WRDS username [minqi]:liuminqi
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# You can find more info here:
# https://www.postgresql.org/docs/9.5/static/libpq-pgpass.html.
# Loading library list...
# Done

# %%
conn.list_libraries()
# Out:
# ['aha',
#  'aha_sample',
#  'ahasamp',
#  'audit',
#  'auditsmp',
#  'bank',
#  'blab',
#  'block',
#  'block_all_new',
#  'boardex',
#  'boardex_trial',
#  'boardsmp',
#  'bvd',
#  'bvdsamp',
#  'calcbench_trial',
#  'calcbnch',
#  'cboe',
#  'centris',
#  'ciq',
#  'ciqsamp',
#  'ciqsamp_transcripts',
#  'cisdm',
#  'cisdmsmp',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_execucomp',
#  'comp_execucomp_new',
#  'comp_global',
#  'comp_global_daily',
#  'comp_segments_hist',
#  'comp_segments_hist_daily',
#  'compa',
#  'compb',
#  'compbd',
#  'compdcur',
#  'compg',
#  'compgd',
#  'comph',
#  'compm',
#  'compmcur',
#  'compnad',
#  'compsamp',
#  'compsamp_snapshot',
#  'compseg',
#  'compsegd',
#  'compsnap',
#  'comscore',
#  'contrib',
#  'contrib_ceo_turnover',
#  'contrib_char_returns',
#  'contrib_general',
#  'contrib_general_new',
#  'contrib_intangible_value',
#  'contrib_kpss',
#  'contrib_liva',
#  'crsp',
#  'crsp_a_stock',
#  'crsp_a_stock_new',
#  'crspa',
#  'crspm',
#  'crspq',
#  'crspsamp',
#  'csmar',
#  'dealscan',
#  'djones',
#  'dmef',
#  'doe',
#  'emdb',
#  'etfg',
#  'etfg_samp',
#  'etfgsamp',
#  'eureka',
#  'eurekahedge_sample',
#  'eursamp',
#  'evts',
#  'execcomp',
#  'factsamp_revere',
#  'factset',
#  'ff',
#  'fisd',
#  'fisdsamp',
#  'fjc',
#  'fjc_linking',
#  'fjc_litigation',
#  'frb',
#  'fssamp',
#  'ftse',
#  'ftsesamp',
#  'ginsight',
#  'ginsight_basic',
#  'ginsight_common',
#  'gmi',
#  'govpx',
#  'govpxsmp',
#  'gsi',
#  'hbase_sample',
#  'hbsamp',
#  'hfr',
#  'hfrsamp',
#  'hfrsamp_hfrdb',
#  'ibes',
#  'ibescorp',
#  'ibeskpi',
#  'ifgr',
#  'ifgrsamp',
#  'ims',
#  'ims_obp_trial',
#  'imssamp',
#  'infogroupsamp_business',
#  'infogroupsamp_residential',
#  'iri',
#  'iss',
#  'issm',
#  'kld',
#  'kld_histall',
#  'ktmine',
#  'ktmine_patents_samp',
#  'ktsamp',
#  'levin',
#  'lspd',
#  'lspdsamp',
#  'lvnsamp',
#  'macrofin',
#  'macrofin_comm_trade',
#  'macrofin_comm_trade_new',
#  'markit',
#  'mfl',
#  'midas',
#  'mrktsamp',
#  'mrktsamp_cds',
#  'mrktsamp_cdx',
#  'mrktsamp_msf',
#  'msfanly',
#  'msfinst',
#  'msrb',
#  'msrbsamp',
#  'nastraq',
#  'omtrial',
#  'optionm',
#  'optionm_all_new',
#  'optionmsamp_europe',
#  'optionmsamp_us',
#  'otc',
#  'otc_endofday',
#  'pacap',
#  'phlx',
#  'pitchsmp',
#  'ppublica',
#  'ppubsamp',
#  'ppubsamp_d4d',
#  'ppubsamp_d4d_new',
#  'preqin',
#  'preqsamp',
#  'preqsamp_all_new',
#  'public',
#  'public_all_new',
#  'pwt',
#  'ravenpack_trial',
#  'rent',
#  'reprisk',
#  'reprisk_sample',
#  'repsamp',
#  'revere',
#  'risk',
#  'risksamp',
#  'rpa',
#  'rpna',
#  'rpnasamp',
#  'sdc',
#  'sdcsamp',
#  'secsamp',
#  'secsamp_all_new',
#  'snapsamp',
#  'snl',
#  'snlsamp',
#  'snlsamp_fig',
#  'sprat',
#  'sustain',
#  'sustsamp',
#  'taq',
#  'taqmsamp',
#  'taqmsec',
#  'taqsamp',
#  'tass',
#  'tfn',
#  'totalq',
#  'totalq_all_new',
#  'toyo',
#  'toyosamp',
#  'tr_13f',
#  'tr_ds',
#  'tr_ibes',
#  'tr_ibes_new',
#  'trace',
#  'trace_enhanced',
#  'trace_standard',
#  'trdssamp',
#  'trdstrm',
#  'tresg',
#  'trown',
#  'trsamp',
#  'trsamp_ds_eq',
#  'trsamp_ds_eq_new',
#  'trsamp_dscom',
#  'trsamp_dsecon',
#  'trsamp_dsfut',
#  'trsdcgs',
#  'trws',
#  'twoiq',
#  'twoiq_samp',
#  'twoiqsmp',
#  'wappsamp',
#  'wcai',
#  'wqa',
#  'wrds_lib_internal',
#  'wrdsapps',
#  'wrdsapps_eushort',
#  'wrdsapps_eushort_new',
#  'wrdsapps_evtstudy_int_ginsight',
#  'wrdsapps_evtstudy_int_ginsight_new',
#  'wrdsapps_finratio',
#  'wrdsapps_finratio_ibes',
#  'wrdsapps_finratio_new',
#  'wrdsapps_link_crsp_factset',
#  'wrdsapps_link_crsp_ibes',
#  'wrdsapps_link_crsp_ibes_new',
#  'wrdsapps_link_crsp_optionm',
#  'wrdsapps_link_crsp_optionm_new',
#  'wrdsapps_patents',
#  'wrdsapps_patents_new',
#  'wrdsapps_windices',
#  'wrdsrpts',
#  'wrdsrpts_rep_usage',
#  'wrdssec',
#  'wrdssec_midas',
#  'wrdssec_midas_new',
#  'zacks',
#  'zacksamp']

# %% [markdown]
# ## 2. WRDS data
#
# I thought it might be interesting to see association between financial data (e.g., net income, sales, etc.) and characteristics of CD&A section. Hence, I downloaded relevant data from 'Compustat Daily Updates - Fundamentals Annual'.

# %% [markdown]
# ### 2.1 Obtain wrds data using sql query
# Common criteria for Compustat Fundamentals Annual (`funda`):
#  - consol = "C" (fully consolidated)
#  - indfmt = "INDL" (industrial format)
#  - datafmt = "STD" (standard format)
#  - posrc = "D" (domestic; USA and Canada)
#
#  Additionally, there is another way to obtain wrds data:
#
#  comp = conn.get_table(library = 'comp',
#                    table ='funda',
#                        columns=['cik', 'conm','fyear', 'ni','sale', 'at','lt'])
# But I felt that using sql was much more convenient.

# %%
comp=conn.raw_sql("""
                  SELECT cik,conm,fyear,ni,sale,at,lt
                  FROM comp.funda
                  WHERE (fyear between '2006' and '2016')
                  AND indfmt='INDL' AND datafmt='STD' AND popsrc='D' AND consol='C'
                  """)
comp.head()
# Out:
#           cik                         conm   fyear      ni      sale  \
# 0  0000002230  ADAMS DIVERSIFIED EQUITY FD  2006.0     NaN       NaN
# 1  0000001750                     AAR CORP  2006.0  58.660  1061.169
# 2  0000061478   ADC TELECOMMUNICATIONS INC  2006.0  65.700  1281.900
# 3  0000319126             AFP IMAGING CORP  2006.0   1.005    24.998
# 4  0000730469          ALPHARMA INC  -CL A  2006.0  82.544   653.828
#
#          at       lt
# 0       NaN      NaN
# 1  1067.633  573.390
# 2  1611.400  737.900
# 3    14.341    3.672
# 4   927.239  203.240

# %% [markdown]
# One problem of this step is that it always took too long to get the dataframe. I have tried to search for more efficient methods but failed.

# %% [markdown]
# ### 2.2 Check basic infomation about the comp dataframe

# %%
comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123581 entries, 0 to 123580
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   cik     95818 non-null   object
#  1   conm    123581 non-null  object
#  2   fyear   123581 non-null  float64
#  3   ni      97603 non-null   float64
#  4   sale    97599 non-null   float64
#  5   at      98138 non-null   float64
#  6   lt      97975 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 6.6+ MB

# %% [markdown]
# ### 2.3 Transform type of 'fyear'

# %%
comp['fyear']=comp['fyear'].astype(int)
comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123581 entries, 0 to 123580
# Data columns (total 7 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   cik     95818 non-null   object
#  1   conm    123581 non-null  object
#  2   fyear   123581 non-null  int64
#  3   ni      97603 non-null   float64
#  4   sale    97599 non-null   float64
#  5   at      98138 non-null   float64
#  6   lt      97975 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 6.6+ MB

# %% [markdown]
# ## 3. Import compensatin excel
# The compensation excel was provided by Professor Greg and was located in the predefined path and renamed as SEC.xlsx.

# %% [markdown]
# ### 3.1 Read excel, transform digit of cik.

# %%
sec=pd.read_excel('SEC.xlsx', index_col=False,converters={'CIK':'{:0>10}'.format})
sec.head()
# Out:
# /Users/minqi/opt/anaconda3/lib/python3.8/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#           CIK   CIK_10            Company Name Form Type  Date Filed  Year  \
# 0  0001292653  1193125      Neutral Tandem Inc   DEF 14A  2010-04-22  2010
# 1  0001013934   950123   STRAYER EDUCATION INC   DEF 14A  2011-03-29  2011
# 2  0000854775  1193125  DIGI INTERNATIONAL INC   DEF 14A  2012-12-05  2012
# 3  0001158463   950123    JETBLUE AIRWAYS CORP   DEF 14A  2011-04-14  2011
# 4  0000059558   950159   LINCOLN NATIONAL CORP   DEF 14A  2013-04-12  2013
#
#   Duplicate CIK-date? Duplicate CIK-year  \
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3                 NaN                NaN
# 4                 NaN                NaN
#
#                 Direct Link to Filing on SEC website     Downloaded Filename  \
# 0  http://www.sec.gov/Archives/edgar/data/1292653...  1292653_2010-04-22.htm
# 1  http://www.sec.gov/Archives/edgar/data/1013934...  1013934_2011-03-29.htm
# 2  http://www.sec.gov/Archives/edgar/data/854775/...   854775_2012-12-05.htm
# 3  http://www.sec.gov/Archives/edgar/data/1158463...  1158463_2011-04-14.htm
# 4  http://www.sec.gov/Archives/edgar/data/59558/0...    59558_2013-04-12.htm
#
#    ... Processed CD&A .txt File Hand checked? # of Images in CD&A Section  \
# 0  ...   1292653_2010-04-22.txt           Yes                         0.0
# 1  ...   1013934_2011-03-29.txt           Yes                         0.0
# 2  ...    854775_2012-12-05.txt           Yes                         1.0
# 3  ...   1158463_2011-04-14.txt           Yes                         1.0
# 4  ...     59558_2013-04-12.txt           Yes                        11.0
#
#    # of Tables in CD&A Section  \
# 0                          3.0
# 1                          0.0
# 2                          5.0
# 3                          4.0
# 4                          2.0
#
#    # of Words in CD&A Section (including tabular content--old version)  \
# 0                                             9625.0
# 1                                             3153.0
# 2                                             5363.0
# 3                                             5133.0
# 4                                             8822.0
#
#    # of Sentences in CD&A (including tabular content--old version)  \
# 0                                              444.0
# 1                                              118.0
# 2                                              240.0
# 3                                              220.0
# 4                                              369.0
#
#    # of Sentences with FLS  (including tabular content--old version)  \
# 0                                              162.0
# 1                                               63.0
# 2                                               69.0
# 3                                               81.0
# 4                                              113.0
#
#    # of Words in CD&A Section  # of Sentences in CD&A  # of Sentences with FLS
# 0                      9035.0                   402.0                    149.0
# 1                       562.0                    15.0                      7.0
# 2                      3819.0                   162.0                     56.0
# 3                      4192.0                   174.0                     67.0
# 4                      6398.0                   253.0                     93.0
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 3.2 Choose useful columns

# %%
sec1=sec.iloc[:,[0,2,5,-8,-7,-6,-5,-4,-3,-2,-1]]
sec1.head()
# Out:
#           CIK            Company Name  Year  # of Images in CD&A Section  \
# 0  0001292653      Neutral Tandem Inc  2010                          0.0
# 1  0001013934   STRAYER EDUCATION INC  2011                          0.0
# 2  0000854775  DIGI INTERNATIONAL INC  2012                          1.0
# 3  0001158463    JETBLUE AIRWAYS CORP  2011                          1.0
# 4  0000059558   LINCOLN NATIONAL CORP  2013                         11.0
#
#    # of Tables in CD&A Section  \
# 0                          3.0
# 1                          0.0
# 2                          5.0
# 3                          4.0
# 4                          2.0
#
#    # of Words in CD&A Section (including tabular content--old version)  \
# 0                                             9625.0
# 1                                             3153.0
# 2                                             5363.0
# 3                                             5133.0
# 4                                             8822.0
#
#    # of Sentences in CD&A (including tabular content--old version)  \
# 0                                              444.0
# 1                                              118.0
# 2                                              240.0
# 3                                              220.0
# 4                                              369.0
#
#    # of Sentences with FLS  (including tabular content--old version)  \
# 0                                              162.0
# 1                                               63.0
# 2                                               69.0
# 3                                               81.0
# 4                                              113.0
#
#    # of Words in CD&A Section  # of Sentences in CD&A  # of Sentences with FLS
# 0                      9035.0                   402.0                    149.0
# 1                       562.0                    15.0                      7.0
# 2                      3819.0                   162.0                     56.0
# 3                      4192.0                   174.0                     67.0
# 4                      6398.0                   253.0                     93.0

# %% [markdown]
# ### 3.3 Transform column names into lower case for the convenience when coding

# %%
sec1.columns=map(str.lower,sec1.columns)
sec1.head()
# Out:
#           cik            company name  year  # of images in cd&a section  \
# 0  0001292653      Neutral Tandem Inc  2010                          0.0
# 1  0001013934   STRAYER EDUCATION INC  2011                          0.0
# 2  0000854775  DIGI INTERNATIONAL INC  2012                          1.0
# 3  0001158463    JETBLUE AIRWAYS CORP  2011                          1.0
# 4  0000059558   LINCOLN NATIONAL CORP  2013                         11.0
#
#    # of tables in cd&a section  \
# 0                          3.0
# 1                          0.0
# 2                          5.0
# 3                          4.0
# 4                          2.0
#
#    # of words in cd&a section (including tabular content--old version)  \
# 0                                             9625.0
# 1                                             3153.0
# 2                                             5363.0
# 3                                             5133.0
# 4                                             8822.0
#
#    # of sentences in cd&a (including tabular content--old version)  \
# 0                                              444.0
# 1                                              118.0
# 2                                              240.0
# 3                                              220.0
# 4                                              369.0
#
#    # of sentences with fls  (including tabular content--old version)  \
# 0                                              162.0
# 1                                               63.0
# 2                                               69.0
# 3                                               81.0
# 4                                              113.0
#
#    # of words in cd&a section  # of sentences in cd&a  # of sentences with fls
# 0                      9035.0                   402.0                    149.0
# 1                       562.0                    15.0                      7.0
# 2                      3819.0                   162.0                     56.0
# 3                      4192.0                   174.0                     67.0
# 4                      6398.0                   253.0                     93.0

# %% [markdown]
# ### 3.4 Transform all the company names into upper case to make company names consistent with those in wrds data.

# %%
sec1['company name']=sec1['company name'].str.upper()
sec1.head()
# Out:
# <ipython-input-12-a69ed2318fbd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sec1['company name']=sec1['company name'].str.upper()
#           cik            company name  year  # of images in cd&a section  \
# 0  0001292653      NEUTRAL TANDEM INC  2010                          0.0
# 1  0001013934   STRAYER EDUCATION INC  2011                          0.0
# 2  0000854775  DIGI INTERNATIONAL INC  2012                          1.0
# 3  0001158463    JETBLUE AIRWAYS CORP  2011                          1.0
# 4  0000059558   LINCOLN NATIONAL CORP  2013                         11.0
#
#    # of tables in cd&a section  \
# 0                          3.0
# 1                          0.0
# 2                          5.0
# 3                          4.0
# 4                          2.0
#
#    # of words in cd&a section (including tabular content--old version)  \
# 0                                             9625.0
# 1                                             3153.0
# 2                                             5363.0
# 3                                             5133.0
# 4                                             8822.0
#
#    # of sentences in cd&a (including tabular content--old version)  \
# 0                                              444.0
# 1                                              118.0
# 2                                              240.0
# 3                                              220.0
# 4                                              369.0
#
#    # of sentences with fls  (including tabular content--old version)  \
# 0                                              162.0
# 1                                               63.0
# 2                                               69.0
# 3                                               81.0
# 4                                              113.0
#
#    # of words in cd&a section  # of sentences in cd&a  # of sentences with fls
# 0                      9035.0                   402.0                    149.0
# 1                       562.0                    15.0                      7.0
# 2                      3819.0                   162.0                     56.0
# 3                      4192.0                   174.0                     67.0
# 4                      6398.0                   253.0                     93.0

# %% [markdown]
# ### 3.5 Look at information about compensation data

# %%
sec1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14994 entries, 0 to 14993
# Data columns (total 11 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   cik                                                                  14994 non-null  object
#  1   company name                                                         14994 non-null  object
#  2   year                                                                 14994 non-null  int64
#  3   # of images in cd&a section                                          13434 non-null  float64
#  4   # of tables in cd&a section                                          13434 non-null  float64
#  5   # of words in cd&a section (including tabular content--old version)  13434 non-null  float64
#  6   # of sentences in cd&a (including tabular content--old version)      100 non-null    float64
#  7   # of sentences with fls  (including tabular content--old version)    100 non-null    float64
#  8   # of words in cd&a section                                           13434 non-null  float64
#  9   # of sentences in cd&a                                               13434 non-null  float64
#  10  # of sentences with fls                                              13434 non-null  float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 1.3+ MB

# %% [markdown]
# ## 4. Merge WRDS data with Executive Compensation Data
#
# ### 4.1 I used left join to merge wrds data with compensation data on cik and year.

# %%
merge=pd.merge(sec1,comp,how='left',left_on=['cik','year'],right_on=['cik','fyear'])
merge.head()
# Out:
#           cik            company name  year  # of images in cd&a section  \
# 0  0001292653      NEUTRAL TANDEM INC  2010                          0.0
# 1  0001013934   STRAYER EDUCATION INC  2011                          0.0
# 2  0000854775  DIGI INTERNATIONAL INC  2012                          1.0
# 3  0001158463    JETBLUE AIRWAYS CORP  2011                          1.0
# 4  0000059558   LINCOLN NATIONAL CORP  2013                         11.0
#
#    # of tables in cd&a section  \
# 0                          3.0
# 1                          0.0
# 2                          5.0
# 3                          4.0
# 4                          2.0
#
#    # of words in cd&a section (including tabular content--old version)  \
# 0                                             9625.0
# 1                                             3153.0
# 2                                             5363.0
# 3                                             5133.0
# 4                                             8822.0
#
#    # of sentences in cd&a (including tabular content--old version)  \
# 0                                              444.0
# 1                                              118.0
# 2                                              240.0
# 3                                              220.0
# 4                                              369.0
#
#    # of sentences with fls  (including tabular content--old version)  \
# 0                                              162.0
# 1                                               63.0
# 2                                               69.0
# 3                                               81.0
# 4                                              113.0
#
#    # of words in cd&a section  # of sentences in cd&a  \
# 0                      9035.0                   402.0
# 1                       562.0                    15.0
# 2                      3819.0                   162.0
# 3                      4192.0                   174.0
# 4                      6398.0                   253.0
#
#    # of sentences with fls                     conm   fyear        ni  \
# 0                    149.0          INTELIQUENT INC  2010.0    32.608
# 1                      7.0  STRATEGIC EDUCATION INC  2011.0   106.044
# 2                     56.0   DIGI INTERNATIONAL INC  2012.0     7.615
# 3                     67.0     JETBLUE AIRWAYS CORP  2011.0    86.000
# 4                     93.0    LINCOLN NATIONAL CORP  2013.0  1244.000
#
#         sale          at          lt
# 0    199.826     315.527      44.244
# 1    627.434     231.133     188.840
# 2    190.558     293.084      22.227
# 3   4504.000    7071.000    5314.000
# 4  11883.000  236945.000  223493.000

# %% [markdown]
# ### 4.2 Make the dataframe more organized

# %%
merge1=merge.sort_values(['cik','year'],ignore_index=True)
merge1.head()
# Out:
#           cik company name  year  # of images in cd&a section  \
# 0  0000001750     AAR CORP  2006                          NaN
# 1  0000001750     AAR CORP  2007                          0.0
# 2  0000001750     AAR CORP  2008                          0.0
# 3  0000001750     AAR CORP  2009                          0.0
# 4  0000001750     AAR CORP  2010                          0.0
#
#    # of tables in cd&a section  \
# 0                          NaN
# 1                          2.0
# 2                          1.0
# 3                          2.0
# 4                          3.0
#
#    # of words in cd&a section (including tabular content--old version)  \
# 0                                                NaN
# 1                                             3824.0
# 2                                             5005.0
# 3                                             5560.0
# 4                                             6034.0
#
#    # of sentences in cd&a (including tabular content--old version)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    # of sentences with fls  (including tabular content--old version)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    # of words in cd&a section  # of sentences in cd&a  \
# 0                         NaN                     NaN
# 1                      3727.0                   165.0
# 2                      4837.0                   207.0
# 3                      5253.0                   207.0
# 4                      5807.0                   236.0
#
#    # of sentences with fls      conm   fyear      ni      sale        at  \
# 0                      NaN  AAR CORP  2006.0  58.660  1061.169  1067.633
# 1                     64.0  AAR CORP  2007.0  75.144  1384.919  1362.010
# 2                     81.0  AAR CORP  2008.0  78.651  1423.976  1377.511
# 3                     79.0  AAR CORP  2009.0  44.628  1352.151  1501.042
# 4                     96.0  AAR CORP  2010.0  69.826  1775.782  1703.727
#
#         lt
# 0  573.390
# 1  776.755
# 2  720.616
# 3  754.692
# 4  868.438

# %% [markdown]
# ### 4.3 Delete the 'fyear' column as it is the same as the 'year' column

# %%
merge2=merge1.drop('fyear',axis=1)
merge2
# Out:
#               cik                       company name  year  \
# 0      0000001750                           AAR CORP  2006
# 1      0000001750                           AAR CORP  2007
# 2      0000001750                           AAR CORP  2008
# 3      0000001750                           AAR CORP  2009
# 4      0000001750                           AAR CORP  2010
# ...           ...                                ...   ...
# 14989  0001645590      HEWLETT PACKARD ENTERPRISE CO  2016
# 14990  0001646383                          CSRA INC.  2016
# 14991  0001649338                       BROADCOM LTD  2016
# 14992  0001650132  FOUR CORNERS PROPERTY TRUST, INC.  2016
# 14993  0001652044                      ALPHABET INC.  2016
#
#        # of images in cd&a section  # of tables in cd&a section  \
# 0                              NaN                          NaN
# 1                              0.0                          2.0
# 2                              0.0                          1.0
# 3                              0.0                          2.0
# 4                              0.0                          3.0
# ...                            ...                          ...
# 14989                         24.0                          2.0
# 14990                          0.0                          6.0
# 14991                          3.0                          6.0
# 14992                          NaN                          NaN
# 14993                          0.0                          1.0
#
#        # of words in cd&a section (including tabular content--old version)  \
# 0                                                    NaN
# 1                                                 3824.0
# 2                                                 5005.0
# 3                                                 5560.0
# 4                                                 6034.0
# ...                                                  ...
# 14989                                            12370.0
# 14990                                             7816.0
# 14991                                             9951.0
# 14992                                                NaN
# 14993                                             4096.0
#
#        # of sentences in cd&a (including tabular content--old version)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14989                                                NaN
# 14990                                                NaN
# 14991                                                NaN
# 14992                                                NaN
# 14993                                                NaN
#
#        # of sentences with fls  (including tabular content--old version)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14989                                                NaN
# 14990                                                NaN
# 14991                                                NaN
# 14992                                                NaN
# 14993                                                NaN
#
#        # of words in cd&a section  # of sentences in cd&a  \
# 0                             NaN                     NaN
# 1                          3727.0                   165.0
# 2                          4837.0                   207.0
# 3                          5253.0                   207.0
# 4                          5807.0                   236.0
# ...                           ...                     ...
# 14989                      8165.0                   332.0
# 14990                      6547.0                   300.0
# 14991                      7099.0                   259.0
# 14992                         NaN                     NaN
# 14993                      3217.0                   159.0
#
#        # of sentences with fls                          conm         ni  \
# 0                          NaN                      AAR CORP     58.660
# 1                         64.0                      AAR CORP     75.144
# 2                         81.0                      AAR CORP     78.651
# 3                         79.0                      AAR CORP     44.628
# 4                         96.0                      AAR CORP     69.826
# ...                        ...                           ...        ...
# 14989                    128.0    HEWLETT PACKARD ENTERPRISE   3161.000
# 14990                     89.0                      CSRA INC    304.000
# 14991                    102.0                           NaN        NaN
# 14992                      NaN  FOUR CORNERS PROPERTY TR INC    156.809
# 14993                     47.0                  ALPHABET INC  19478.000
#
#             sale          at         lt
# 0       1061.169    1067.633    573.390
# 1       1384.919    1362.010    776.755
# 2       1423.976    1377.511    720.616
# 3       1352.151    1501.042    754.692
# 4       1775.782    1703.727    868.438
# ...          ...         ...        ...
# 14989  50123.000   79679.000  48161.000
# 14990   4993.000    4888.000   4529.000
# 14991        NaN         NaN        NaN
# 14992    124.115     937.151    467.034
# 14993  90272.000  167497.000  28461.000
#
# [14994 rows x 16 columns]

# %%
merge2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14994 entries, 0 to 14993
# Data columns (total 16 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   cik                                                                  14994 non-null  object
#  1   company name                                                         14994 non-null  object
#  2   year                                                                 14994 non-null  int64
#  3   # of images in cd&a section                                          13434 non-null  float64
#  4   # of tables in cd&a section                                          13434 non-null  float64
#  5   # of words in cd&a section (including tabular content--old version)  13434 non-null  float64
#  6   # of sentences in cd&a (including tabular content--old version)      100 non-null    float64
#  7   # of sentences with fls  (including tabular content--old version)    100 non-null    float64
#  8   # of words in cd&a section                                           13434 non-null  float64
#  9   # of sentences in cd&a                                               13434 non-null  float64
#  10  # of sentences with fls                                              13434 non-null  float64
#  11  conm                                                                 14616 non-null  object
#  12  ni                                                                   14605 non-null  float64
#  13  sale                                                                 14605 non-null  float64
#  14  at                                                                   14607 non-null  float64
#  15  lt                                                                   14572 non-null  float64
# dtypes: float64(12), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# ### 4.4 Drop duplicates

# %%
merge3=merge2.drop_duplicates(subset=['cik','company name','year'],keep='first')
merge3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14755 entries, 0 to 14993
# Data columns (total 16 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   cik                                                                  14755 non-null  object
#  1   company name                                                         14755 non-null  object
#  2   year                                                                 14755 non-null  int64
#  3   # of images in cd&a section                                          13319 non-null  float64
#  4   # of tables in cd&a section                                          13319 non-null  float64
#  5   # of words in cd&a section (including tabular content--old version)  13319 non-null  float64
#  6   # of sentences in cd&a (including tabular content--old version)      100 non-null    float64
#  7   # of sentences with fls  (including tabular content--old version)    100 non-null    float64
#  8   # of words in cd&a section                                           13319 non-null  float64
#  9   # of sentences in cd&a                                               13319 non-null  float64
#  10  # of sentences with fls                                              13319 non-null  float64
#  11  conm                                                                 14384 non-null  object
#  12  ni                                                                   14373 non-null  float64
#  13  sale                                                                 14373 non-null  float64
#  14  at                                                                   14375 non-null  float64
#  15  lt                                                                   14341 non-null  float64
# dtypes: float64(12), int64(1), object(3)
# memory usage: 1.9+ MB
